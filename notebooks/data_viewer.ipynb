# %%
import pandas as pd

# %%
topics = pd.read_excel('../data/raw/topics.xlsx')
projects = pd.read_excel('../data/raw/project.xlsx')
euroscivoc = pd.read_excel('../data/raw/euroSciVoc.xlsx')
orgs = pd.read_excel('../data/raw/organization.xlsx')
# Out:
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
projects['startDate']= pd.to_datetime(projects['startDate'],errors = 'coerce')
projects['endDate']= pd.to_datetime(projects['endDate'],errors = 'coerce')
projects.info()

from datetime import datetime
filterdate = datetime(2024,1,1)
projects_fil = projects[projects['startDate']>=filterdate]
projects_fil = projects_fil[projects_fil['endDate']>=datetime(2027,9,25)]
projects_fil
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14970 entries, 0 to 14969
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  14970 non-null  int64
#  1   acronym             14970 non-null  object
#  2   status              14970 non-null  object
#  3   title               14970 non-null  object
#  4   startDate           14970 non-null  datetime64[ns]
#  5   endDate             14970 non-null  datetime64[ns]
#  6   totalCost           14970 non-null  object
#  7   ecMaxContribution   14970 non-null  object
#  8   legalBasis          14970 non-null  object
#  9   topics              14970 non-null  object
#  10  ecSignatureDate     14968 non-null  object
#  11  frameworkProgramme  14970 non-null  object
#  12  masterCall          14970 non-null  object
#  13  subCall             14970 non-null  object
#  14  fundingScheme       14969 non-null  object
#  15  nature              0 non-null      float64
#  16  objective           14970 non-null  object
#  17  contentUpdateDate   14970 non-null  object
#  18  rcn                 14970 non-null  int64
#  19  grantDoi            14911 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(15)
# memory usage: 2.3+ MB
#               id           acronym  status  \
# 1      101193001  Impact Monitor 2  SIGNED
# 2      101165479          RE-TWIST  SIGNED
# 3      101191725           InFlaMe  SIGNED
# 4      101191867           EPISODE  SIGNED
# 5      101147312            SAGELI  SIGNED
# ...          ...               ...     ...
# 14953  101130249          WASTE2H2  SIGNED
# 14954  101186701              LEAF  SIGNED
# 14957  101161603       E.T.COMPACT  SIGNED
# 14959  101161137          FROSTBIT  SIGNED
# 14961  101129638            ICONIC  SIGNED
#
#                                                    title  startDate  \
# 1                                       Impact Monitor 2 2025-02-01
# 2      REinforcement TWInning SysTems: from collabora... 2025-02-01
# 3      Counter-acting the pandemic potential of flavi... 2025-01-01
# 4      European Produced sustaInable SODium-ion battE... 2024-12-01
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# ...                                                  ...        ...
# 14953  PLASTIC WASTE VALORIZATION TO CLEAN H2 AND DEC... 2024-03-01
# 14954  SeLf-powered self-rEshaping Autarkic skin For ... 2025-03-01
# 14957  COMPACT AND PROPELLANT-LESS ELECTRODYNAMIC TET... 2024-10-01
# 14959  First Regenerative sOlid-STate Barocaloric ref... 2024-10-01
# 14961  In-situ & operando organiC electrochemical tra... 2024-05-01
#
#          endDate   totalCost ecMaxContribution   legalBasis  \
# 1     2028-01-31     3000000           3000000  HORIZON.2.5
# 2     2030-01-31     1500000           1500000  HORIZON.1.1
# 3     2028-12-31   7995922,4         7995922,4  HORIZON.2.1
# 4     2028-05-31           0        6597981,39  HORIZON.2.5
# 5     2027-12-31  4975670,75        4975669,75  HORIZON.2.5
# ...          ...         ...               ...          ...
# 14953 2028-02-29  2984716,25        2984716,25  HORIZON.3.1
# 14954 2028-02-29  2565321,25        2565321,25  HORIZON.3.1
# 14957 2027-09-30     3972890           3972890  HORIZON.3.1
# 14959 2028-09-30   3427222,5         3427222,5  HORIZON.3.1
# 14961 2028-04-30     2664940           2664940  HORIZON.3.1
#
#                                             topics ecSignatureDate  \
# 1                        HORIZON-CL5-2024-D5-01-09      2024-12-02
# 2                                     ERC-2024-STG      2024-12-02
# 3                  HORIZON-HLTH-2024-DISEASE-08-20      2024-12-02
# 4                        HORIZON-CL5-2024-D2-01-02      2024-11-29
# 5                        HORIZON-CL5-2023-D2-02-02      2024-11-18
# ...                                            ...             ...
# 14953        HORIZON-EIC-2023-PATHFINDEROPEN-01-01      2023-11-16
# 14954        HORIZON-EIC-2024-PATHFINDEROPEN-01-01      2024-11-06
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-05      2024-06-16
# 14959  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-01      2024-06-10
# 14961        HORIZON-EIC-2023-PATHFINDEROPEN-01-01      2023-11-08
#
#       frameworkProgramme                                masterCall  \
# 1                HORIZON                    HORIZON-CL5-2024-D5-01
# 2                HORIZON                              ERC-2024-STG
# 3                HORIZON              HORIZON-HLTH-2024-DISEASE-08
# 4                HORIZON                    HORIZON-CL5-2024-D2-01
# 5                HORIZON                    HORIZON-CL5-2023-D2-02
# ...                  ...                                       ...
# 14953            HORIZON        HORIZON-EIC-2023-PATHFINDEROPEN-01
# 14954            HORIZON        HORIZON-EIC-2024-PATHFINDEROPEN-01
# 14957            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14959            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14961            HORIZON        HORIZON-EIC-2023-PATHFINDEROPEN-01
#
#                                         subCall fundingScheme  nature  \
# 1                        HORIZON-CL5-2024-D5-01   HORIZON-RIA     NaN
# 2                                  ERC-2024-STG   HORIZON-ERC     NaN
# 3                  HORIZON-HLTH-2024-DISEASE-08   HORIZON-RIA     NaN
# 4                        HORIZON-CL5-2024-D2-01    HORIZON-IA     NaN
# 5                        HORIZON-CL5-2023-D2-02   HORIZON-RIA     NaN
# ...                                         ...           ...     ...
# 14953        HORIZON-EIC-2023-PATHFINDEROPEN-01   HORIZON-EIC     NaN
# 14954        HORIZON-EIC-2024-PATHFINDEROPEN-01   HORIZON-EIC     NaN
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01   HORIZON-EIC     NaN
# 14959  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01   HORIZON-EIC     NaN
# 14961        HORIZON-EIC-2023-PATHFINDEROPEN-01   HORIZON-EIC     NaN
#
#                                                objective    contentUpdateDate  \
# 1      Impact Monitor 2 is a project to deliver a coh...  2024-12-12 11:00:46
# 2      "The concept of digital twins promises to revo...  2024-12-12 11:42:39
# 3      To strengthen EU's ability to fight DENV and W...  2024-12-12 11:00:45
# 4      The main mission for EPISODE is to develop a n...  2024-12-12 11:00:44
# 5      SAGELi aims to develop safer materials and cel...  2024-12-12 11:00:23
# ...                                                  ...                  ...
# 14953  Daily basis used plastics cause a huge amount ...  2023-11-21 10:11:05
# 14954  We will combine 3D reshaping, energy harvestin...  2024-11-15 16:54:05
# 14957  E.T.COMPACT is aimed at reaching technology re...  2024-06-24 10:42:44
# 14959  Greenhouse gas emissions for refrigeration sys...  2024-06-17 12:50:54
# 14961  Ultra-flexible, conformable and implantable ar...  2024-09-06 17:45:33
#
#           rcn           grantDoi
# 1      268041  10.3030/101193001
# 2      268016  10.3030/101165479
# 3      268032  10.3030/101191725
# 4      268027  10.3030/101191867
# 5      267735  10.3030/101147312
# ...       ...                ...
# 14953  258308  10.3030/101130249
# 14954  267357  10.3030/101186701
# 14957  264516  10.3030/101161603
# 14959  264057  10.3030/101161137
# 14961  258154  10.3030/101129638
#
# [3350 rows x 20 columns]

# %%
projectIDs = projects_fil['id'].tolist()

# %%
orgs
# Out:
#        projectID  projectAcronym  organisationID       vatNumber  \
# 0      101113245  EIT Digital BP       897714437     GB267089763
# 1      101113245  EIT Digital BP       888552011    BE0700827077
# 2      101113245  EIT Digital BP       887518282  SE802506144401
# 3      101113245  EIT Digital BP       893135746     ESG87900874
# 4      101113245  EIT Digital BP       887937031      FI28441107
# ...          ...             ...             ...             ...
# 97391  101131516       FlexRICAN       983194329  SE556016864201
# 97392  101131516       FlexRICAN       910554618    BE0628655020
# 97393  101131516       FlexRICAN       919998053  SE768200001801
# 97394  101131516       FlexRICAN       999997930   FR40180089013
# 97395  101131516       FlexRICAN       999470541     DE140213784
#
#                                                     name           shortName  \
# 0                                         EIT DIGITAL UK  EIT DIGITAL UK LTD
# 1                                EIT DIGITAL ACCELERATOR                 NaN
# 2                                     EIT DIGITAL SWEDEN                 NaN
# 3                                      EIT DIGITAL SPAIN                 NaN
# 4                                 EIT DIGITAL FINLAND RY                 NaN
# ...                                                  ...                 ...
# 97391                         ALFA LAVAL TECHNOLOGIES AB                 NaN
# 97392                 EUROPEAN MAGNETIC FIELD LABORATORY        EMFL - AISBL
# 97393                    EUROPEAN SPALLATION SOURCE ERIC                 NaN
# 97394  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                CNRS
# 97395            HELMHOLTZ-ZENTRUM DRESDEN-ROSSENDORF EV                HZDR
#
#          SME activityType                                             street  \
# 0      False          OTH                                  46 WICKLOW STREET
# 1      False          OTH                                      RUE GUIMARD 7
# 2      False          OTH                                       TORSGATAN 11
# 3      False          OTH  EDIFICIO IMDEA SOFTWARE CAMPUS DE MONTEGANCEDO...
# 4      False          OTH                                        MAARINTIE 6
# ...      ...          ...                                                ...
# 97391  False          PRC                                    RUDEBOKSVAGEN 1
# 97392  False          OTH                                    RUE DU TRONE 98
# 97393  False          PUB                                 ODARSLOVSVAGEN 113
# 97394  False          REC                                  RUE MICHEL ANGE 3
# 97395  False          REC                           BAUTZNER LANDSTRASSE 400
#
#        postCode  ...                                        contactForm  \
# 0      WC1X 9JH  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 1          1040  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 2        111 23  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 3         28223  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 4         02150  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# ...         ...  ...                                                ...
# 97391    221 00  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97392      1050  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97393    224 84  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97394     75794  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97395     01328  ...  https://ec.europa.eu/info/funding-tenders/oppo...
#
#          contentUpdateDate      rcn order         role ecContribution  \
# 0      2023-06-28 16:59:04  1981607   1.0   thirdParty            0.0
# 1      2023-06-28 16:59:04  1973441   1.0   thirdParty            0.0
# 2      2023-06-28 16:59:04  1981597   1.0   thirdParty            0.0
# 3      2023-06-28 16:59:04  1981603   1.0   thirdParty            0.0
# 4      2023-06-28 16:59:04  1981600   1.0   thirdParty            0.0
# ...                    ...      ...   ...          ...            ...
# 97391  2024-09-06 18:33:46  3099835   7.0  participant       106250.0
# 97392  2024-09-06 18:33:46  1965488   5.0  participant        37500.0
# 97393  2024-09-06 18:33:46  2720567   1.0  coordinator      1935725.0
# 97394  2024-09-06 18:33:46  1905572   3.0  participant      1118375.0
# 97395  2024-09-06 18:33:46  1909706   4.0  participant        78500.0
#
#       netEcContribution  totalCost  endOfParticipation active
# 0                   0.0          0               False    NaN
# 1             1740000.0          0               False    NaN
# 2               55875.0          0               False    NaN
# 3             1427500.0          0               False    NaN
# 4             1426250.0          0               False    NaN
# ...                 ...        ...                 ...    ...
# 97391          106250.0          0               False    NaN
# 97392           37500.0          0               False    NaN
# 97393         1935725.0          0               False    NaN
# 97394         1086382.0          0               False    NaN
# 97395           78500.0          0               False    NaN
#
# [97396 rows x 25 columns]

# %%
orgsinproj = orgs[orgs['projectID'].isin(projectIDs)]
orgsinproj
# Out:
#        projectID    projectAcronym  organisationID       vatNumber  \
# 8      101193001  Impact Monitor 2       998616262    BE0476966024
# 9      101193001  Impact Monitor 2       999987066  NL002760551B01
# 10     101193001  Impact Monitor 2       999994438   FR36775722879
# 11     101193001  Impact Monitor 2       999981731     DE121965658
# 12     101193001  Impact Monitor 2       984454068    BE0826094461
# ...          ...               ...             ...             ...
# 97357  101129638            ICONIC       999849326   FR55180092025
# 97358  101129638            ICONIC       999849908     DE811264317
# 97359  101129638            ICONIC       999989782  NL001932706B01
# 97360  101129638            ICONIC       999847677     GB248837911
# 97361  101129638            ICONIC       997640733   HR64218323816
#
#                                                     name  \
# 8                            TRANSPORT & MOBILITY LEUVEN
# 9      STICHTING KONINKLIJK NEDERLANDS LUCHT - EN RUI...
# 10     OFFICE NATIONAL D'ETUDES ET DE RECHERCHES AERO...
# 11         DEUTSCHES ZENTRUM FUR LUFT - UND RAUMFAHRT EV
# 12              EASN TECHNOLOGY INNOVATION SERVICES BVBA
# ...                                                  ...
# 97357                             INSTITUT MINES-TELECOM
# 97358                               UNIVERSITAT BAYREUTH
# 97359                        RIJKSUNIVERSITEIT GRONINGEN
# 97360                    QUEEN MARY UNIVERSITY OF LONDON
# 97361                               SVEUCILISTE U RIJECI
#
#                                           shortName    SME activityType  \
# 8                                               TML   True          PRC
# 9      Royal Netherlands Aerospace Centre Amsterdam  False          REC
# 10                                            ONERA  False          REC
# 11                                              DLR  False          REC
# 12                                         EASN TIS   True          PRC
# ...                                             ...    ...          ...
# 97357                                           NaN  False          HES
# 97358                                           NaN  False          HES
# 97359                                           NaN  False          HES
# 97360                                          QMUL  False          HES
# 97361                                         UNIRI  False          HES
#
#                           street postCode  ...  \
# 8             DIESTSESTEENWEG 71     3010  ...
# 9            ANTHONY FOKKERWEG 2  1059 CM  ...
# 10          CHEMIN DE LA HUNIERE    91120  ...
# 11                   LINDER HOHE    51147  ...
# 12            TERWEIDENSTRAAT 28     3440  ...
# ...                          ...      ...  ...
# 97357  19 PLACE MARGUERITE PEREY    91120  ...
# 97358     UNIVERSITATSSTRASSE 30    95447  ...
# 97359             Broerstraat  5   9712CP  ...
# 97360          327 MILE END ROAD   E1 4NS  ...
# 97361    TRG BRACE MAZURANICA 10    51000  ...
#
#                                              contactForm    contentUpdateDate  \
# 8      https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 9      https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 10     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 11     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 12     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# ...                                                  ...                  ...
# 97357  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 17:45:33
# 97358  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 17:45:33
# 97359  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 17:45:33
# 97360  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 17:45:33
# 97361  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 17:45:33
#
#            rcn order               role ecContribution netEcContribution  \
# 8      1911517  10.0        participant      121375.00         121375.00
# 9      1905669   5.0        participant      473911.50         473911.50
# 10     1905624   6.0        participant      474681.00         474681.00
# 11     1905579   1.0        coordinator     1158016.25        1158016.25
# 12     1911071   4.0        participant       75035.00          75035.00
# ...        ...   ...                ...            ...               ...
# 97357  1907037   1.0        coordinator      767572.50         767572.50
# 97358  1906865   4.0        participant      364772.50         364772.50
# 97359  1905576   2.0        participant      547682.50         547682.50
# 97360  1905573   8.0  associatedPartner            NaN              0.00
# 97361  1948995   3.0        participant      349452.50         349452.50
#
#         totalCost  endOfParticipation active
# 8          121375               False    NaN
# 9        473911,5               False    NaN
# 10         474681               False    NaN
# 11     1158016,25               False    NaN
# 12          75035               False    NaN
# ...           ...                 ...    ...
# 97357    767572,5               False    NaN
# 97358    364772,5               False    NaN
# 97359    547682,5               False    NaN
# 97360           0               False    NaN
# 97361    349452,5               False    NaN
#
# [27184 rows x 25 columns]

# %%
print (orgsinproj['country'].unique())
# Out:
# ['BE' 'NL' 'FR' 'DE' 'ES' 'IT' 'UK' 'EL' 'AT' 'CZ' 'EE' 'LT' 'PT' 'AM'
#  'SK' 'MT' 'PL' 'TN' 'HU' 'CH' 'IL' 'HR' 'IE' 'BG' 'FI' 'RO' 'MZ' 'ET'
#  'NO' 'MA' 'LU' 'SN' 'ZA' 'SE' 'CM' 'NG' 'KE' 'RW' 'ML' 'BF' 'TZ' 'CO'
#  'TR' 'CY' 'SI' 'RS' 'US' 'UA' 'DK' 'LB' 'JP' 'NZ' 'AU' 'BD' 'GT' 'IN'
#  'GH' 'ZM' 'LV' 'CV' 'CA' 'CD' 'CI' 'UG' 'MV' 'BA' 'MK' 'PE' 'GW' 'AO'
#  'ST' 'KH' 'CN' 'GE' 'SG' 'TG' 'FO' 'BR' 'KR' nan 'BJ' 'PG' 'IS' 'DZ' 'EG'
#  'ZW' 'JO' 'MW' 'GA' 'MX' 'AR' 'PY' 'CR' 'BO' 'NP' 'MO' 'MY' 'UZ' 'MD'
#  'TH' 'LK' 'KZ' 'LA' 'ID' 'VN' 'KG' 'AL' 'XK' 'CU' 'TM' 'TJ' 'AZ' 'MN'
#  'CL' 'BI' 'CG' 'GL' 'TW' 'MG' 'UY' 'SV' 'CF' 'HK' 'BW' 'EC' 'ME' 'PK'
#  'SA' 'IR' 'AW' 'GN' 'AE' 'DO' 'SR' 'PF' 'DJ' 'TD' 'PH' 'MC' 'LI' 'QA']

# %%
projectsIDS_with_widening = orgsinproj[orgsinproj['country'].isin(['EL','BG','HR','CZ','EE','HU','LV','LT','MT','PL','PT','RO','SK','SI',
                                                                   'AL','BA','AM','FO','GE','XK','MD','ME','MK','RS','TN','TR','UA','MA',
                                                                   'GP','GF','MQ','YT','CY'])]
projectsIDS_with_widening= projectsIDS_with_widening['projectID'].tolist()

# %%
projects_no_widening = projects_fil[~projects_fil['id'].isin(projectsIDS_with_widening)]
projects_no_widening
# Out:
#               id         acronym  status  \
# 2      101165479        RE-TWIST  SIGNED
# 5      101147312          SAGELI  SIGNED
# 12     101167472  2DPolyMembrane  SIGNED
# 14     101167218   SKIN2DTRONICS  SIGNED
# 15     101167181      MetaDivide  SIGNED
# ...          ...             ...     ...
# 14938  101129798        W-BioCat  SIGNED
# 14947  101161583      Green SWaP  SIGNED
# 14953  101130249        WASTE2H2  SIGNED
# 14954  101186701            LEAF  SIGNED
# 14957  101161603     E.T.COMPACT  SIGNED
#
#                                                    title  startDate  \
# 2      REinforcement TWInning SysTems: from collabora... 2025-02-01
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# 12     Ultrathin Two-Dimensional Polymer Heterostruct... 2025-04-01
# 14     SKIN-like TWO-Dimensional materials-based elec... 2025-05-01
# 15     Metabolism-driven division of minimal cell-lik... 2025-01-01
# ...                                                  ...        ...
# 14938  TUNGSTEN BIOCATALYSIS – HEAVY METAL ENZYMES FO... 2024-02-01
# 14947         Green Solar-to-propellant Water Propulsion 2024-10-01
# 14953  PLASTIC WASTE VALORIZATION TO CLEAN H2 AND DEC... 2024-03-01
# 14954  SeLf-powered self-rEshaping Autarkic skin For ... 2025-03-01
# 14957  COMPACT AND PROPELLANT-LESS ELECTRODYNAMIC TET... 2024-10-01
#
#          endDate   totalCost ecMaxContribution   legalBasis  \
# 2     2030-01-31     1500000           1500000  HORIZON.1.1
# 5     2027-12-31  4975670,75        4975669,75  HORIZON.2.5
# 12    2031-03-31    10000000          10000000  HORIZON.1.1
# 14    2031-04-30     9896897           9896897  HORIZON.1.1
# 15    2030-12-31     5000000           5000000  HORIZON.1.1
# ...          ...         ...               ...          ...
# 14938 2028-01-31  2430574,75        2430574,75  HORIZON.3.1
# 14947 2028-09-30  3997916,25        3997916,25  HORIZON.3.1
# 14953 2028-02-29  2984716,25        2984716,25  HORIZON.3.1
# 14954 2028-02-29  2565321,25        2565321,25  HORIZON.3.1
# 14957 2027-09-30     3972890           3972890  HORIZON.3.1
#
#                                             topics ecSignatureDate  \
# 2                                     ERC-2024-STG      2024-12-02
# 5                        HORIZON-CL5-2023-D2-02-02      2024-11-18
# 12                                    ERC-2024-SyG      2024-11-29
# 14                                    ERC-2024-SyG      2024-11-29
# 15                                    ERC-2024-SyG      2024-11-30
# ...                                            ...             ...
# 14938        HORIZON-EIC-2023-PATHFINDEROPEN-01-01      2023-09-29
# 14947  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-05      2024-06-12
# 14953        HORIZON-EIC-2023-PATHFINDEROPEN-01-01      2023-11-16
# 14954        HORIZON-EIC-2024-PATHFINDEROPEN-01-01      2024-11-06
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-05      2024-06-16
#
#       frameworkProgramme                                masterCall  \
# 2                HORIZON                              ERC-2024-STG
# 5                HORIZON                    HORIZON-CL5-2023-D2-02
# 12               HORIZON                              ERC-2024-SyG
# 14               HORIZON                              ERC-2024-SyG
# 15               HORIZON                              ERC-2024-SyG
# ...                  ...                                       ...
# 14938            HORIZON        HORIZON-EIC-2023-PATHFINDEROPEN-01
# 14947            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14953            HORIZON        HORIZON-EIC-2023-PATHFINDEROPEN-01
# 14954            HORIZON        HORIZON-EIC-2024-PATHFINDEROPEN-01
# 14957            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
#
#                                         subCall    fundingScheme  nature  \
# 2                                  ERC-2024-STG      HORIZON-ERC     NaN
# 5                        HORIZON-CL5-2023-D2-02      HORIZON-RIA     NaN
# 12                                 ERC-2024-SyG  HORIZON-ERC-SYG     NaN
# 14                                 ERC-2024-SyG  HORIZON-ERC-SYG     NaN
# 15                                 ERC-2024-SyG  HORIZON-ERC-SYG     NaN
# ...                                         ...              ...     ...
# 14938        HORIZON-EIC-2023-PATHFINDEROPEN-01      HORIZON-EIC     NaN
# 14947  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01      HORIZON-EIC     NaN
# 14953        HORIZON-EIC-2023-PATHFINDEROPEN-01      HORIZON-EIC     NaN
# 14954        HORIZON-EIC-2024-PATHFINDEROPEN-01      HORIZON-EIC     NaN
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01      HORIZON-EIC     NaN
#
#                                                objective    contentUpdateDate  \
# 2      "The concept of digital twins promises to revo...  2024-12-12 11:42:39
# 5      SAGELi aims to develop safer materials and cel...  2024-12-12 11:00:23
# 12     Current separation technology is crucial for m...  2024-12-12 11:00:39
# 14     The goal of SKIN2DTRONICS is to demonstrate th...  2024-12-12 11:00:38
# 15     Building a synthetic cell from molecular compo...  2024-12-12 11:00:44
# ...                                                  ...                  ...
# 14938  Europe needs a sustainable chemical industry w...  2024-09-06 18:33:35
# 14947  Similar to terrestrial photosynthesis, whereby...  2024-06-17 11:20:50
# 14953  Daily basis used plastics cause a huge amount ...  2023-11-21 10:11:05
# 14954  We will combine 3D reshaping, energy harvestin...  2024-11-15 16:54:05
# 14957  E.T.COMPACT is aimed at reaching technology re...  2024-06-24 10:42:44
#
#           rcn           grantDoi
# 2      268016  10.3030/101165479
# 5      267735  10.3030/101147312
# 12     268018  10.3030/101167472
# 14     268017  10.3030/101167218
# 15     268020  10.3030/101167181
# ...       ...                ...
# 14938  257320  10.3030/101129798
# 14947  264065  10.3030/101161583
# 14953  258308  10.3030/101130249
# 14954  267357  10.3030/101186701
# 14957  264516  10.3030/101161603
#
# [1929 rows x 20 columns]

# %%
orgs_no_widening = orgs[orgs['projectID'].isin(projects_no_widening['id'].tolist())]
orgs_no_widening
# Out:
#        projectID projectAcronym  organisationID      vatNumber  \
# 18     101165479       RE-TWIST       999986290   BE0407626464
# 19     101165479       RE-TWIST       999698006   BE0407185709
# 45     101147312         SAGELI       912743326    ESB98896137
# 46     101147312         SAGELI       881331040  IT03941241204
# 47     101147312         SAGELI       999980470    DE122624631
# ...          ...            ...             ...            ...
# 97338  101161603    E.T.COMPACT       987017875  IT09776431000
# 97339  101161603    E.T.COMPACT       877994240    ESB56464050
# 97340  101161603    E.T.COMPACT       957686433    ATU57640814
# 97341  101161603    E.T.COMPACT       999899572    ESQ2818029G
# 97342  101161603    E.T.COMPACT       999897729    DE188369991
#
#                                           name  \
# 18               UNIVERSITE LIBRE DE BRUXELLES
# 19     VON KARMAN INSTITUTE FOR FLUID DYNAMICS
# 45                                 LOMARTOV SL
# 46                            POWER4FUTURE SPA
# 47               FORSCHUNGSZENTRUM JULICH GMBH
# ...                                        ...
# 97338                      HALOCELL EUROPE SRL
# 97339                          PERSEI SPACE SL
# 97340  SUNPLUGGED - SOLARE ENERGIESYSTEME GMBH
# 97341         UNIVERSIDAD CARLOS III DE MADRID
# 97342          TECHNISCHE UNIVERSITAET DRESDEN
#
#                                           shortName    SME activityType  \
# 18                                              ULB  False          HES
# 19     VON KARMAN INSTITUTE FOR FLUID DYNAMICS- VKI   True          REC
# 45                                              NaN   True          PRC
# 46                                     POWER4FUTURE  False          PRC
# 47                                              FZJ  False          REC
# ...                                             ...    ...          ...
# 97338                           Halocell Europe srl   True          PRC
# 97339                                           NaN   True          PRC
# 97340                                    SUNPLUGGED   True          PRC
# 97341                                          UC3M  False          HES
# 97342                                           TUD  False          HES
#
#                              street postCode  ...  \
# 18     AVENUE FRANKLIN ROOSEVELT 50     1050  ...
# 19          Waterloose Steenweg, 72     1640  ...
# 45               CALLE ALFARERIA, 3    46100  ...
# 46          VIA STELLONI PONENTE 33    40012  ...
# 47           WILHELM JOHNEN STRASSE    52428  ...
# ...                             ...      ...  ...
# 97338     VIALE CASTRO PRETORIO 122    00185  ...
# 97339   AVDA GREGORIO PECES BARBA 1    28919  ...
# 97340        MINDELHEIMER STRASSE 6     6130  ...
# 97341              CALLE MADRID 126    28903  ...
# 97342           HELMHOLTZSTRASSE 10    01069  ...
#
#                                              contactForm    contentUpdateDate  \
# 18     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:42:39
# 19     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:42:39
# 45     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:23
# 46     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:23
# 47     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:23
# ...                                                  ...                  ...
# 97338  https://ec.europa.eu/info/funding-tenders/oppo...  2024-06-24 10:42:44
# 97339  https://ec.europa.eu/info/funding-tenders/oppo...  2024-06-24 10:42:44
# 97340  https://ec.europa.eu/info/funding-tenders/oppo...  2024-06-24 10:42:44
# 97341  https://ec.europa.eu/info/funding-tenders/oppo...  2024-06-24 10:42:44
# 97342  https://ec.europa.eu/info/funding-tenders/oppo...  2024-06-24 10:42:44
#
#            rcn order         role ecContribution netEcContribution  totalCost  \
# 18     1905620   2.0  participant       728750.0          728750.0     728750
# 19     1905618   1.0  coordinator       771250.0          771250.0     771250
# 45     3146679   8.0  participant       281250.0          281250.0     281250
# 46     1990776  11.0  participant       156125.0           89687.5     156125
# 47     1905734   4.0  participant       425297.5          425297.5   425297,5
# ...        ...   ...          ...            ...               ...        ...
# 97338  2075941   5.0  participant       728125.0          728125.0     728125
# 97339  1990129   7.0  participant       151875.0          151875.0     151875
# 97340  1942780   6.0  participant       660500.0          660500.0     660500
# 97341  1908365   1.0  coordinator       470875.0          470875.0     470875
# 97342  1905682   4.0  participant       665912.5          665912.5   665912,5
#
#        endOfParticipation active
# 18                  False    NaN
# 19                  False    NaN
# 45                  False    NaN
# 46                  False    NaN
# 47                  False    NaN
# ...                   ...    ...
# 97338               False    NaN
# 97339               False    NaN
# 97340               False    NaN
# 97341               False    NaN
# 97342               False    NaN
#
# [6220 rows x 25 columns]

# %%
euroscivoc
# Out:
#        projectID        euroSciVocCode  \
# 0      101165479                     /
# 1      101165479                     /
# 2      101165479                     /
# 3      101191725                     /
# 4      101188572  /25/75/461/1239/1737
# ...          ...                   ...
# 44031  101130454                     /
# 44032  101130454                     /
# 44033  101131516                     /
# 44034  101131516                     /
# 44035  101131516                     /
#
#                                           euroSciVocPath  \
# 0      /natural sciences/physical sciences/thermodyna...
# 1      /engineering and technology/electrical enginee...
# 2      /engineering and technology/environmental engi...
# 3      /natural sciences/biological sciences/biochemi...
# 4      /engineering and technology/mechanical enginee...
# ...                                                  ...
# 44031  /natural sciences/biological sciences/ecology/...
# 44032  /engineering and technology/industrial biotech...
# 44033  /engineering and technology/environmental engi...
# 44034  /engineering and technology/electrical enginee...
# 44035  /social sciences/political sciences/government...
#
#                    euroSciVocTitle  euroSciVocDescription
# 0                   thermodynamics                    NaN
# 1                           drones                    NaN
# 2                 energy and fuels                    NaN
# 3                         proteins                    NaN
# 4                         aircraft                    NaN
# ...                            ...                    ...
# 44031                   ecosystems                    NaN
# 44032                 biomaterials                    NaN
# 44033             renewable energy                    NaN
# 44034  electric power distribution                    NaN
# 44035           government systems                    NaN
#
# [44036 rows x 5 columns]

# %%
euroscivoc_proj_no_widening = euroscivoc[euroscivoc['projectID'].isin(projects_no_widening['id'].tolist())]

# %%
euroscivoc_proj_no_widening['euroSciVocTitle'].unique()
# Out:
# array(['thermodynamics', 'drones', 'energy and fuels', 'graphene',
#        'polymer sciences', 'geometry', 'sensors', 'metalloids',
#        'synthetic biology', 'proteins', 'biophysics', 'genomes',
#        'mortality', 'virology', 'fertility', 'microscopy', 'antibiotics',
#        'immunisation', 'geographic information systems', 'pandemics',
#        'vaccines', 'malaria', 'obstetrics', 'epidemiology',
#        'cervical cancer', 'DNA viruses', 'alzheimer', 'entrepreneurship',
#        'biomolecules', 'immunotherapy', 'spacecraft', 'optical sensors',
#        'exoplanetology', 'cells technologies', 'databases', 'aircraft',
#        'aeronautical engineering', 'cryptography', 'ecosystems',
#        'enzymes', 'cereals', 'coal', 'topology', 'diabetes',
#        'ophthalmology', 'carbon fibers', 'antivirals', 'software',
#        'multidrug resistance', 'neutrinos', 'astrophysics', 'employment',
#        'prime numbers', 'human rights violations', 'history', 'DNA',
#        'pathophysiology', 'pathology', 'social inequalities', 'dementia',
#        'stroke', 'drug discovery', 'tuberculosis', 'pharmaceutical drugs',
#        'hepatitis B', 'HIV', 'ocean engineering', 'wind power',
#        'nongovernmental organizations', 'mining and mineral processing',
#        'civil society', 'sustainable economy', 'human rights',
#        'data processing', 'surgery', 'fluorescence lifetime imaging',
#        'oncology', 'photons', 'satellite technology',
#        'post-transition metals', 'semiconductivity', 'marine biology',
#        'business models', 'climatic changes', 'hydrocarbons', 'catalysis',
#        'folklore', 'government systems', 'quantum physics',
#        'quantum computers', 'nanophotonics', 'immunology', 'lipids',
#        'condensed matter physics', 'spectroscopy', 'analytical chemistry',
#        'molecular and chemical physics', 'physical chemistry',
#        'cognitive neuroscience', 'computational intelligence', 'islam',
#        'drinking water treatment processes', 'bacteriology',
#        'atomic physics', 'genetics', 'amines', 'plate tectonics',
#        'proteomics', 'evolutionary biology', 'biological interactions',
#        'game theory', 'gene therapy', 'cell biology', 'homeostasis',
#        'two-dimensional nanostructures', 'fisheries',
#        'production economics', 'epigenetics', 'cardiovascular diseases',
#        'kidney diseases', 'artificial intelligence', 'journalism',
#        'democracy', 'gender equality', 'didactics', 'ecology',
#        'religions', 'paleoclimatology', 'tissue engineering',
#        'biomaterials', 'crisis management', 'natural disasters',
#        'urban studies', 'deep learning', 'fluid mechanics',
#        'multiphysics', 'algebraic geometry', 'law', 'cell polarity',
#        'signal processing', 'natural language processing',
#        'computational science', 'machine learning', 'mathematical model',
#        'anatomy and morphology', 'computer vision', 'productivity',
#        'agriculture', 'nucleotides', 'public health', 'RNA',
#        'nano-materials', 'governance', 'ancient history',
#        'digital humanities', 'solid-state physics', 'optics',
#        'quantum optics', 'mammalogy', 'obesity', 'electron microscopy',
#        'economics', 'psychology', 'history of literature', 'mathematics',
#        'molecular engineering', 'dark matter', 'nuclear decay',
#        'laser physics', 'neurobiology', 'fluid dynamics',
#        'numerical analysis', 'racial inequality', 'christianity',
#        'globalization', 'electrolysis', 'internet of things',
#        'wearable medical technology ', 'personalized medicine',
#        'magnetic resonance imaging', 'super resolution microscopy',
#        'visual arts', 'contemporary history', 'anthropology',
#        'system software', 'psycholinguistics', 'relational databases',
#        'organic chemistry', 'public policies', 'inclusive education',
#        'biochemistry', 'biogeochemistry', 'biodiversity conservation',
#        'materials engineering', 'protein folding', 'mutation',
#        'functional analysis', 'parkinson', 'quantum field theory',
#        'theoretical physics', 'linguistics', 'cognitive psychology',
#        'philosophy', 'seismology', 'neutron stars', 'revolutions',
#        'asteroseismology', 'biological sciences',
#        'medical and health sciences', 'epilepsy', 'physiology',
#        'constitutional law', 'pattern recognition', 'transition metals',
#        'data mining', 'data science', 'internet', 'electromagnetism',
#        'space exploration', 'natural satellites', 'radar', 'geophysics',
#        'demography', 'graph theory', 'climate change adaptation',
#        'ethnology', 'human migrations', 'manufacturing engineering',
#        'evolutionary ecology', 'microbiology', 'reproductive biology',
#        'ergonomics', 'dynamical systems', 'computer hardware',
#        'developmental biology', 'drug resistance', 'breast cancer',
#        'phycology', 'eukaryotic genomes', 'carbohydrates',
#        'confocal microscopy', 'biosensors', 'cardiology',
#        'facial recognition', 'public administration', 'crystals',
#        'business and management', 'alkaline earth metals',
#        'foreign policy', 'inflammatory diseases', 'nutrition',
#        'pollution', 'structural biology', 'judaism',
#        'environmental sciences', 'nanomedicine', 'soft robotics',
#        'implants', 'particle accelerator', 'fermions', 'quarks',
#        'social issues', 'entomology', 'lab on a chip',
#        'wastewater treatment processes', 'renewable energy',
#        'alkali metals', 'graft versus host disease', 'transplantation',
#        'ultrafast lasers', 'superconductivity', 'grains and oilseeds',
#        'plant breeding', 'embryology', 'modern history',
#        'gender inequality', 'arts', 'medieval history', 'nucleic acids',
#        'organic reactions', 'nanotechnology', 'additive manufacturing',
#        'photochemistry', 'differential equations', 'big bang',
#        'physical cosmology', 'statistical mechanics',
#        'conformal field theory', 'complex analysis',
#        'statistics and probability', 'autoimmune diseases',
#        'pharmacology and pharmacy', 'supervised learning',
#        'bayesian statistics', 'dramaturgy', 'colorectal cancer',
#        'photocatalysis', 'freight transport', 'oceanography',
#        'medical biotechnology', 'human trafficking', 'planets',
#        'black holes', 'chromosomes', 'biocatalysis',
#        'popular music studies', 'gender studies', 'arithmetics',
#        'algebra', 'essays', 'literary criticism', 'social psychology',
#        'metabolic engineering', 'solar energy', 'food safety',
#        'animal husbandry', 'zoonosis', 'antibiotic resistance', 'colors',
#        'gluons', 'corruption', 'teleology', 'vascular diseases',
#        'gravitational waves', 'supernova', 'comets', 'history of islam',
#        'criminology', 'science and technology studies',
#        'vegetable growing', 'schizophrenia', 'neurology', 'taxation',
#        'particle physics', 'plasma physics', 'astronomy',
#        'law enforcement', 'bureaucracy', 'political economy', 'commerce',
#        'microtechnology', 'ethnoarchaeology', 'archaeometry',
#        'eastern religions', 'social anthropology',
#        'partial differential equations', 'prostate cancer',
#        'pancreatic cancer', 'horticulture', 'bioarchaeology',
#        'political philosophy', 'elections',
#        'computer and information sciences', 'operator algebra',
#        'public services', 'prehistory', 'ethology',
#        'obsessive-compulsive disorder', 'stem cells',
#        'physical oceanography', 'botany', 'family studies', 'archaeology',
#        'linear algebra', 'logarithmic functions', 'soft matter physics',
#        'aliphatic compounds', 'heuristic programming', 'fruit growing',
#        'bose-einstein condensates', 'literature studies',
#        'cultural anthropology', 'geotechnics', 'planetary geology',
#        'reinforcement learning', 'autonomous robots',
#        'generative artificial intelligence', 'medicinal chemistry',
#        'knowledge engineering', 'lung cancer', 'computed tomography',
#        'symplectic topology', 'algebraic topology', 'string theory',
#        'molecular biology', 'computer processors', 'smart sensors',
#        'inflammatory bowel disease', 'textiles', 'virtual reality',
#        'fibers', 'political policies', 'remote sensing',
#        'health care services', 'climatology',
#        'carbon capture engineering', 'photovoltaic', 'ornithology',
#        'terrorism', 'big data', 'armed conflicts', 'microfluidics',
#        'mass spectrometry', 'ethnomusicology', 'cinematography',
#        'observational astronomy', 'census', 'squamous cell carcinoma',
#        'relativistic mechanics', 'spintronics', 'microelectronics',
#        'amyotrophic lateral sclerosis', 'optical astronomy',
#        'galaxy evolution', 'hydrology', 'epistemology', 'nursing',
#        'sleep disorders', 'leukemia', 'microeconomics', 'supercomputers',
#        'psychotherapy', 'psychiatry', 'coating and films',
#        'mathematical logic', 'sustainable transport', 'drug allergy',
#        'RNA viruses', 'invertebrate zoology', 'asthma', 'heredity',
#        'mental processes', 'electric energy', 'ceramics', 'combinatorics',
#        'biosphera', 'glaciology', 'political communication', 'melanoma',
#        'sustainable building', 'dendrochronology', 'forestry', 'geology',
#        'recycling', 'biomass', 'electric batteries', 'irrigation',
#        'edaphology', 'compost', 'physical anthropology', 'quantum gases',
#        'behavioural psychology', 'optoelectronics',
#        'semisupervised learning', 'sustainability sciences',
#        'social sciences', 'mobile phones', 'meteorology',
#        'autonomous vehicles', 'discrete mathematics', 'health sciences',
#        'cell signaling', 'planetary sciences', 'simulation software',
#        'ultrasound', 'hepatology', 'ontology', 'medieval philosophy',
#        'active learning', 'agronomy', 'library sciences', 'arboriculture',
#        'dairy', 'infectious diseases', 'posttraumatic stress disorder',
#        'biosensing', 'combined heat and power', 'natural gas',
#        'land management', 'ethical theories', 'solar thermal',
#        'energy conversion', 'composites', 'sexual health', 'automation',
#        'liver cancer', 'organ on a chip', 'ecological restoration',
#        'solid mechanics', 'chemical sciences', 'nuclear physics',
#        'nuclear energy', 'robotics', 'data protection', 'smart cities',
#        'heat engineering', 'inorganic compounds', 'anxiety disorders',
#        'mathematical physics', 'radio astronomy', 'celestial mechanics',
#        'nonlinear optics', 'environmental engineering',
#        'transportation engineering', 'political violence',
#        'electrochemistry', 'comparative morphology', 'mechatronics',
#        'swarm robotics', 'bioreactors', 'physiotherapy',
#        'medical engineering', 'atmospheric turbulence',
#        'diagnostic imaging', 'drainage basins', 'mycology',
#        'nuclear fusion', 'electrocatalysis', 'cavity optomechanics',
#        'separation technologies', 'air pollution engineering',
#        'limnology', 'plant protection', 'bioelectrochemistry',
#        'sign language', 'noble gases',
#        'earth and related environmental sciences', 'cartography',
#        'navigation systems', 'knot theory', 'sociology', 'histology',
#        'international law', 'human rights law', 'fuel cells',
#        'hepatitis C', 'coronaviruses', 'econometrics', 'asteroids',
#        'meteorites', 'cosmochemistry', 'extragalactic astronomy',
#        'digital electronics', 'modern philosophy', 'influenza',
#        'behavioural ecology', 'apidology', 'invasive species',
#        'apiculture', 'volatile organic compounds',
#        'developmental psychology', 'object detection', 'social work',
#        'gerontology', 'international protection of human rights',
#        'transfer learning', 'geochemistry', 'literary genres',
#        'sexual violence', 'transport', 'hydrogen energy',
#        'control systems', 'lubrication', 'microwave technology',
#        'sustainable agriculture', 'political transitions',
#        'viral genomes', 'fetal medicine', 'macroeconomics',
#        'chemical process engineering', 'classical mechanics',
#        'aromatic compounds', 'sedimentology', 'other medical sciences',
#        'social biomedical sciences', 'primatology', 'prokaryotic genomes',
#        'subtractive manufacturing', 'telecommunications networks',
#        'genetic engineering', 'molecular genetics', 'distillation',
#        'computational fluid dynamics', 'climatic zones', 'palaeontology',
#        'quantum chemistry', 'nanocrystals', 'regional human rights',
#        'art history', 'silviculture', 'landscape ecology',
#        'image recognition', 'unsupervised learning',
#        'molecular evolution', 'general language studies', 'acoustics',
#        'architectural design', 'history of medicine', 'aldehydes',
#        'metaphysics', 'radio frequency', 'polylactic acid',
#        'fluid statics', 'polyhydroxyalkanoates', 'metallurgy',
#        'health economics', 'frugal artificial intelligence', 'humanities',
#        'surgical procedures', 'thermodynamic engineering',
#        'modern and contemporary art', 'coastal ecosystems', '5G',
#        'computational neuroscience', 'cardiac arrhythmia',
#        'political sciences', 'rheumatology', 'bladder cancer',
#        'pulsed lasers', 'ethnolichenology', 'paleoecology',
#        'gastroenterology', 'pharmacokinetics', 'concentrated solar power',
#        'electric power transmission', 'nuclear medicine',
#        'mechanical engineering', 'contemporary philosophy',
#        'women’s studies', 'wave power', 'medical genetics', 'eHealth',
#        'bioremediation', 'postnatal care', 'childbirth',
#        'multiple sclerosis', 'cetology', 'motion analysis',
#        'ozone depletion', 'cultural and economic geography',
#        'graphic design', 'cell metabolism', 'family planning', 'ethics',
#        'synthetic fuels', 'chemical engineering',
#        'industrial biotechnology', 'data networks', 'pneumology',
#        'volcanology', 'operating systems', 'biofuels', 'alcohols',
#        'molecular neuroscience', 'mineralogy', 'petrology',
#        'atmospheric circulation', 'bioeconomy', 'performing arts',
#        'leptons', 'innovation management', 'infrared astronomy',
#        'literary theory', 'natural sciences', 'hydroelectricity',
#        'world wide web', 'critical care medicine', 'fibre optics',
#        'dermatology', 'video games', 'special education', 'e-governance',
#        'public transport', 'geomorphology', 'penology',
#        'electric vehicles', 'skin cancer', 'tribology', 'muslim culture',
#        'waste treatment processes', 'anaesthesiology',
#        'isotope geochemistry', 'radiation chemistry', 'troposphere',
#        'ebola', 'absorption spectroscopy', 'white dwarfs',
#        'solar physics', 'languages and literature',
#        'diagnostic technologies', 'modeling of diseases spread',
#        'computational creativity', 'water management',
#        'nuclear engineering', 'fermentation', 'surgical specialties',
#        'waste management', 'ecohydrology', 'toxicology',
#        'global navigation satellite system', 'telecommunications',
#        'mobile network', 'freshwater ecosystems', 'endocrinology',
#        'cytology', 'otorhinolaryngology', 'robotic surgery',
#        'parasitology', 'clinical neurology', 'mathematical analysis',
#        'knowledge organization', 'palynology', 'underwater archaeology',
#        'substance abuse', 'geothermal energy', 'ideologies',
#        'laboratory samples analysis', 'allergology', 'pedagogy',
#        'calorimetry', 'organic acids', 'biochemical engineering',
#        'nuclear waste management', 'solar astronomy',
#        'physical geography', 'optical networks',
#        'seismic risk management', 'microseisms', 'atmospheric pressure',
#        'higgs bosons', 'airport engineering', 'applied mathematics',
#        'radiochemistry', 'electric power generation', 'halogens',
#        'natural resources management', 'arteriosclerosis',
#        'sustainable architecture', 'structural engineering'], dtype=object)

# %%
scivocpathlist = euroscivoc_proj_no_widening['euroSciVocPath'].tolist()

# %%
paths = ",".join(scivocpathlist)
print (paths)
# Out:
# /natural sciences/physical sciences/thermodynamics,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/robotics/autonomous robots/drones,/engineering and technology/environmental engineering/energy and fuels,/engineering and technology/nanotechnology/nano-materials/two-dimensional nanostructures/graphene,/natural sciences/chemical sciences/polymer sciences,/natural sciences/mathematics/pure mathematics/geometry,/engineering and technology/environmental engineering/energy and fuels,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/sensors,/natural sciences/chemical sciences/inorganic chemistry/metalloids,/natural sciences/biological sciences/synthetic biology,/natural sciences/biological sciences/biochemistry/biomolecules/proteins,/natural sciences/biological sciences/biophysics,/natural sciences/biological sciences/genetics/genomes,/social sciences/sociology/demography/mortality,/natural sciences/biological sciences/microbiology/virology,/natural sciences/biological sciences/biochemistry/biomolecules/proteins,/social sciences/sociology/demography/fertility,/natural sciences/physical sciences/optics/microscopy,/medical and health sciences/basic medicine/pharmacology and pharmacy/pharmaceutical drugs/antibiotics,/social sciences/sociology/demography/mortality,/medical and health sciences/basic medicine/immunology/immunisation,/natural sciences/earth and related environmental sciences/physical geography/cartography/geographic information systems,/medical and health sciences/health sciences/public health/epidemiology/pandemics,/medical and health sciences/basic medicine/pharmacology and pharmacy/pharmaceutical drugs/vaccines,/medical and health sciences/health sciences/infectious diseases/malaria,/medical and health sciences/basic medicine/immunology/immunisation,/medical and health sciences/basic medicine/pharmacology and pharmacy/pharmaceutical drugs/vaccines,/medical and health sciences/basic medicine/immunology/immunisation,/natural sciences/biological sciences/microbiology/virology,/medical and health sciences/health sciences/public health/epidemiology/pandemics,/medical and health sciences/basic medicine/pharmacology and pharmacy/pharmaceutical drugs/vaccines,/medical and health sciences/clinical medicine/obstetrics,/medical and health sciences/health sciences/public health/epidemiology,/medical and health sciences/basic medicine/pharmacology and pharmacy/pharmaceutical drugs/vaccines,/medical and health sciences/clinical medicine/oncology/cervical cancer,/medical and health sciences/health sciences/infectious diseases/DNA viruses,/medical and health sciences/basic medicine/neurology/dementia/alzheimer,/social sciences/economics and business/business and management/entrepreneurship,/natural sciences/biological sciences/biochemistry/biomolecules,/medical and health sciences/basic medicine/immunology/immunotherapy,/engineering and technology/mechanical engineering/vehicle engineering/aerospace engineering/astronautical engineering/spacecraft,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/sensors/optical sensors,/natural sciences/physical sciences/astronomy/planetary sciences/planets/exoplanetology,/medical and health sciences/medical biotechnology/cells technologies,/natural sciences/computer and information sciences/databases,/engineering and technology/mechanical engineering/vehicle engineering/aerospace engineering/aircraft,/engineering and technology/mechanical engineering/vehicle engineering/aerospace engineering/aeronautical engineering,/natural sciences/computer and information sciences/computer security/cryptography,/natural sciences/biological sciences/ecology/ecosystems,/natural sciences/biological sciences/biochemistry/biomolecules/proteins/enzymes,/agricultural sciences/agriculture, forestry, and fi ...

# %%
paths = paths.replace('/',',')
paths = paths.replace(',,',',')

# %%
paths
# Out:
# ',natural sciences,physical sciences,thermodynamics,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,robotics,autonomous robots,drones,engineering and technology,environmental engineering,energy and fuels,engineering and technology,nanotechnology,nano-materials,two-dimensional nanostructures,graphene,natural sciences,chemical sciences,polymer sciences,natural sciences,mathematics,pure mathematics,geometry,engineering and technology,environmental engineering,energy and fuels,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,sensors,natural sciences,chemical sciences,inorganic chemistry,metalloids,natural sciences,biological sciences,synthetic biology,natural sciences,biological sciences,biochemistry,biomolecules,proteins,natural sciences,biological sciences,biophysics,natural sciences,biological sciences,genetics,genomes,social sciences,sociology,demography,mortality,natural sciences,biological sciences,microbiology,virology,natural sciences,biological sciences,biochemistry,biomolecules,proteins,social sciences,sociology,demography,fertility,natural sciences,physical sciences,optics,microscopy,medical and health sciences,basic medicine,pharmacology and pharmacy,pharmaceutical drugs,antibiotics,social sciences,sociology,demography,mortality,medical and health sciences,basic medicine,immunology,immunisation,natural sciences,earth and related environmental sciences,physical geography,cartography,geographic information systems,medical and health sciences,health sciences,public health,epidemiology,pandemics,medical and health sciences,basic medicine,pharmacology and pharmacy,pharmaceutical drugs,vaccines,medical and health sciences,health sciences,infectious diseases,malaria,medical and health sciences,basic medicine,immunology,immunisation,medical and health sciences,basic medicine,pharmacology and pharmacy,pharmaceutical drugs,vaccines,medical and health sciences,basic medicine,immunology,immunisation,natural sciences,biological sciences,microbiology,virology,medical and health sciences,health sciences,public health,epidemiology,pandemics,medical and health sciences,basic medicine,pharmacology and pharmacy,pharmaceutical drugs,vaccines,medical and health sciences,clinical medicine,obstetrics,medical and health sciences,health sciences,public health,epidemiology,medical and health sciences,basic medicine,pharmacology and pharmacy,pharmaceutical drugs,vaccines,medical and health sciences,clinical medicine,oncology,cervical cancer,medical and health sciences,health sciences,infectious diseases,DNA viruses,medical and health sciences,basic medicine,neurology,dementia,alzheimer,social sciences,economics and business,business and management,entrepreneurship,natural sciences,biological sciences,biochemistry,biomolecules,medical and health sciences,basic medicine,immunology,immunotherapy,engineering and technology,mechanical engineering,vehicle engineering,aerospace engineering,astronautical engineering,spacecraft,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,sensors,optical sensors,natural sciences,physical sciences,astronomy,planetary sciences,planets,exoplanetology,medical and health sciences,medical biotechnology,cells technologies,natural sciences,computer and information sciences,databases,engineering and technology,mechanical engineering,vehicle engineering,aerospace engineering,aircraft,engineering and technology,mechanical engineering,vehicle engineering,aerospace engineering,aeronautical engineering,natural sciences,computer and information sciences,computer security,cryptography,natural sciences,biological sciences,ecology,ecosystems,natural sciences,biological sciences,biochemistry,biomolecules,proteins,enzymes,agricultural sciences,agriculture, forestry, and fisheries,agriculture,grains and oilseeds,cereals,e ...

# %%
refs = paths.split(',')
refs = set(refs)
refs = [r.strip() for r in refs]
refs
# Out:
# ['',
#  'aerospace engineering',
#  'food safety',
#  'lung cancer',
#  'microeconomics',
#  'climatology',
#  'lipids',
#  'optoelectronics',
#  'human rights',
#  'confocal microscopy',
#  'cell polarity',
#  'archaeology',
#  'stem cells',
#  'inflammatory bowel disease',
#  'contemporary history',
#  'particle accelerator',
#  'RNA viruses',
#  'physical geography',
#  'biodiversity conservation',
#  'bureaucracy',
#  'object detection',
#  'breast cancer',
#  'modern and contemporary art',
#  'smart cities',
#  'ethics and religion',
#  'semisupervised learning',
#  'nuclear decay',
#  'computational science',
#  'animal husbandry',
#  'ancient history',
#  'digital humanities',
#  'inorganic chemistry',
#  'particle physics',
#  'metalloids',
#  'astrophysics',
#  'history of islam',
#  'automation',
#  'quantum computers',
#  'combined heat and power',
#  'humanities',
#  'radiology',
#  'clinical neurology',
#  'modern philosophy',
#  'forestry',
#  'solar thermal',
#  'genomes',
#  'colorectal cancer',
#  'cognitive neuroscience',
#  'fluid statics',
#  'sustainable agriculture',
#  'computational neuroscience',
#  'law enforcement',
#  'popular music studies',
#  'classical mechanics',
#  'sedimentology',
#  'spectroscopy',
#  'emergency medicine',
#  'machine learning',
#  'nutrition',
#  'signal processing',
#  'agricultural sciences',
#  'lubrication',
#  'aeronautical engineering',
#  'psycholinguistics',
#  'information engineering',
#  'clinical medicine',
#  'medical engineering',
#  'epistemology',
#  'absorption spectroscopy',
#  'drug resistance',
#  'agricultural biotechnology',
#  'mental processes',
#  'fibre optics',
#  'autoimmune diseases',
#  'ecosystem-based management',
#  'political policies',
#  'political economy',
#  'smart sensors',
#  'organic chemistry',
#  'ecology',
#  'virology',
#  'psychiatry',
#  'hepatitis B',
#  'cell biology',
#  'otorhinolaryngology',
#  'digital electronics',
#  'climatic changes',
#  'molecular and chemical physics',
#  'globalization',
#  'public transport',
#  'artificial intelligence',
#  'supercomputers',
#  'social sciences',
#  'hydrology',
#  'post-transition metals',
#  'governance',
#  'nanocrystals',
#  'theoretical physics',
#  'geology',
#  'journalism',
#  'substance abuse',
#  'family studies',
#  'crystals',
#  'prostate cancer',
#  'rheumatology',
#  'alcohols',
#  'pulsed lasers',
#  'data mining',
#  'biomolecules',
#  'critical care medicine',
#  'kidney diseases',
#  'data science',
#  'dramaturgy',
#  'environmental biotechnology',
#  'subtractive manufacturing',
#  'surgical specialties',
#  'planetary geology',
#  'chromosomes',
#  'supervised learning',
#  'productivity',
#  'renewable energy',
#  'reproductive biology',
#  'cell signaling',
#  'pedagogy',
#  'political sciences',
#  'ethical theories',
#  'seismic risk management',
#  'mortality',
#  'thermodynamic engineering',
#  'prokaryotic genomes',
#  'energy conversion',
#  'nuclear medicine',
#  'textiles',
#  'geographic information systems',
#  '5G',
#  'coating and films',
#  'childbirth',
#  'dendrochronology',
#  'graphene',
#  'composites',
#  'biophysics',
#  'health care services',
#  'graphic design',
#  'health sciences',
#  'histology',
#  'cultural anthropology',
#  'environmental sciences',
#  'geometry',
#  'asteroids',
#  'airport engineering',
#  'food technology',
#  'foreign policy',
#  'proteomics',
#  'dairy',
#  'history of literature',
#  'arts',
#  'robotics',
#  'census',
#  'pathology',
#  'medical and health sciences',
#  'social anthropology',
#  'limnology',
#  'engineering and technology',
#  'heredity',
#  'irrigation',
#  'mining and mineral processing',
#  'computer and information sciences',
#  'mathematical logic',
#  'infectious diseases',
#  'carbon fibers',
#  'carbon capture engineering',
#  'ebola',
#  'electrolysis',
#  'computational intelligence',
#  'internet',
#  'revolutions',
#  'constitutional law',
#  'nuclear energy',
#  'fossil energy',
#  'mathematical physics',
#  'molecular genetics',
#  'cetology',
#  'fluid dynamics',
#  'analytical chemistry',
#  'DNA viruses',
#  'wind power',
#  'hydrocarbons',
#  'bioeconomy',
#  'complex analysis',
#  'bioarchaeology',
#  'materials engineering',
#  'transportation engineering',
#  'sustainable economy',
#  'production economics',
#  'anatomy and morphology',
#  'didactics',
#  'laboratory samples analysis',
#  'cardiology',
#  'exoplanetology',
#  'other humanities',
#  'entrepreneurship',
#  'fibers',
#  'atmospheric turbulence',
#  'metabolic engineering',
#  'nanophotonics',
#  'neutrinos',
#  'heuristic programming',
#  'transplantation',
#  'physiotherapy',
#  'geophysics',
#  'electronic engineering',
#  'drug allergy',
#  'land management',
#  'pharmacokinetics',
#  'ideologies',
#  'christianity',
#  'computer hardware',
#  'pollution',
#  'waste management',
#  'microwave technology',
#  'mathematics',
#  'civil society',
#  'biosensors',
#  'bioplastics',
#  'microseisms',
#  'higgs bosons',
#  'power engineering',
#  'taxation',
#  'gravitational waves',
#  'human rights law',
#  'science and technology studies',
#  'climatic zones',
#  'prime numbers',
#  'comparative morphology',
#  'microelectronics',
#  'quantum chemistry',
#  'concentrated solar power',
#  'domestic animals',
#  'mechanical engineering',
#  'additive manufacturing',
#  'psychotherapy',
#  'fermentation',
#  'public policies',
#  'paleoecology',
#  'water engineering',
#  'ophthalmology',
#  'natural resources management',
#  'biofuels',
#  'contemporary philosophy',
#  'nanotechnology',
#  'corruption',
#  'motion analysis',
#  'literary criticism',
#  'computer security',
#  'data processing',
#  'knot theory',
#  'business models',
#  'information engineering',
#  'galactic astronomy',
#  'musicology',
#  'autonomous robots',
#  'gastroenterology',
#  'political transitions',
#  'squamous cell carcinoma',
#  'autonomous vehicles',
#  'radar',
#  'metallurgy',
#  'social inequalities',
#  'underwater archaeology',
#  'plant protection',
#  'silviculture',
#  'climate change adaptation',
#  'medical genetics',
#  'air pollution engineering',
#  'computer vision',
#  'relativistic mechanics',
#  'alzheimer',
#  'satellite technology',
#  'ethnology',
#  'sexual health',
#  'structural engineering',
#  'data protection',
#  'troposphere',
#  'ecohydrology',
#  'mutation',
#  'cardiovascular diseases',
#  'lab on a chip',
#  'inorganic compounds',
#  'terrorism',
#  'vehicle engineering',
#  'developmental psychology',
#  'fluid mechanics',
#  'mycology',
#  'volcanology',
#  'schizophrenia',
#  'big bang',
#  'natural gas',
#  'human rights violations',
#  'nucleotides',
#  'quantum optics',
#  'asthma',
#  'combinatorics',
#  'sign language',
#  'behavioural ecology',
#  'solar astronomy',
#  'law',
#  'modern history',
#  'software',
#  'generative artificial intelligence',
#  'homeostasis',
#  'geochemistry',
#  'pharmacology and pharmacy',
#  'edaphology',
#  'electromagnetism and electronics',
#  'gene therapy',
#  'applied mathematics',
#  'literature studies',
#  'judaism',
#  'ultrasound',
#  'bladder cancer',
#  'penology',
#  'medieval philosophy',
#  'biological behavioural sciences',
#  'RNA',
#  'waste treatment processes',
#  'modeling of diseases spread',
#  'hepatitis C',
#  'bayesian statistics',
#  'biomaterials',
#  'drug discovery',
#  'enzymes',
#  'water treatment processes',
#  'physical anthropology',
#  'solid-state physics',
#  'optical sensors',
#  'gluons',
#  'mass spectrometry',
#  'physical oceanography',
#  'spintronics',
#  'urban studies',
#  'fisheries',
#  'protein folding',
#  'influenza',
#  'economics and business',
#  'architectural design',
#  'atmospheric sciences',
#  'posttraumatic stress disorder',
#  'nuclear waste management',
#  'industrial relations',
#  'cinematography',
#  'fetal medicine',
#  'magnetic resonance imaging',
#  'obstetrics',
#  'neurology',
#  'entomology',
#  'drones',
#  'nongovernmental organizations',
#  'radiochemistry',
#  'tissue engineering',
#  'cell metabolism',
#  'oceanography',
#  'electric power generation',
#  'immunisation',
#  'polylactic acid',
#  'plate tectonics',
#  'white dwarfs',
#  'phycology',
#  'genetics',
#  'freshwater ecosystems',
#  'natural sciences',
#  'nuclear fusion',
#  'geothermal energy',
#  'coastal ecosystems',
#  'glaciology',
#  'elections',
#  'string theory',
#  'nuclear engineering',
#  'carbohydrates',
#  'immunotherapy',
#  'condensed matter physics',
#  'radio frequency',
#  'halogens',
#  'environmental engineering',
#  'horticulture',
#  'soil sciences',
#  'ontology',
#  'discrete mathematics',
#  'apiculture',
#  'internet of things',
#  'special education',
#  'amyotrophic lateral sclerosis',
#  'surgical procedures',
#  'grains and oilseeds',
#  'relational databases',
#  'computer processors',
#  'robotic surgery',
#  'urban engineering',
#  'antivirals',
#  'super resolution microscopy',
#  'compost',
#  'cardiac arrhythmia',
#  'satellite navigation system',
#  'microfluidics',
#  'geotechnics',
#  'landscape ecology',
#  'leukemia',
#  'ultrafast lasers',
#  'active learning',
#  'atmospheric circulation',
#  'zoology',
#  'literary theory',
#  'melanoma',
#  'alkaline earth metals',
#  'eukaryotic genomes',
#  'sensors',
#  'pure mathematics',
#  'databases',
#  'extragalactic astronomy',
#  'tuberculosis',
#  'teleology',
#  'game theory',
#  'primatology',
#  'biocatalysis',
#  'bose-einstein condensates',
#  'synthetic biology',
#  'embryology',
#  'women’s studies',
#  'metaphysics',
#  'public services',
#  'human migrations',
#  'cartography',
#  'radio technology',
#  'plant breeding',
#  'fermions',
#  'electric power transmission',
#  'soft matter physics',
#  'microbiology',
#  'cereals',
#  'sustainability sciences',
#  'atmospheric pressure',
#  'operator algebra',
#  'nano-materials',
#  'angiology',
#  'deep learning',
#  'bioelectrochemistry',
#  'distillation',
#  'chemical engineering',
#  'marine biology',
#  'anxiety disorders',
#  'hydrogen energy',
#  'electrochemistry',
#  'alkali metals',
#  'gender studies',
#  'ethics',
#  'natural language processing',
#  'biosphera',
#  'armed conflicts',
#  'ceramics',
#  'transfer learning',
#  'pancreatic cancer',
#  'anaesthesiology',
#  'nanomedicine',
#  'ocean engineering',
#  'innovation management',
#  'malaria',
#  'cavity optomechanics',
#  'sociology',
#  'vascular diseases',
#  'social geography',
#  'prehistory',
#  'civil engineering',
#  'solar energy',
#  'psychology',
#  'organ on a chip',
#  'world wide web',
#  'biological interactions',
#  'criminology',
#  'liver cancer',
#  'human trafficking',
#  'energy and fuels',
#  'navigation systems',
#  'global navigation satellite system',
#  'antibiotics',
#  'neutron stars',
#  'social biomedical sciences',
#  'diagnostic imaging',
#  'molecular evolution',
#  'swarm robotics',
#  'aliphatic compounds',
#  'literary genres',
#  'social work',
#  'multiple sclerosis',
#  'history and archaeology',
#  'noble gases',
#  'optical astronomy',
#  'photochemistry',
#  'dementia',
#  'history',
#  'crisis management',
#  'ethnomusicology',
#  'drinking water treatment processes',
#  'basic medicine',
#  'philosophy',
#  'statistical mechanics',
#  'proteins',
#  'HIV',
#  'biosensing',
#  'computed tomography',
#  'pharmaceutical drugs',
#  'econometrics',
#  'petrology',
#  'catalysis',
#  'islam',
#  'nephrology',
#  'molecular engineering',
#  'palaeontology',
#  'algebraic geometry',
#  'soft robotics',
#  'wastewater treatment processes',
#  'isotope geochemistry',
#  'comets',
#  'public health',
#  'photons',
#  'behavioural psychology',
#  'ecological restoration',
#  'paleoclimatology',
#  'conformal field theory',
#  'frugal artificial intelligence',
#  'celestial mechanics',
#  'drainage basins',
#  'video games',
#  'macroeconomics',
#  'synthetic fuels',
#  'telecommunications',
#  'bacteriology',
#  'algebraic topology',
#  'galaxy evolution',
#  'parkinson',
#  'sleep disorders',
#  'recycling',
#  'planetary sciences',
#  'oncology',
#  'medicinal chemistry',
#  'statistics and probability',
#  'family planning',
#  'social issues',
#  'media and communications',
#  'industrial biotechnology',
#  'molecular neuroscience',
#  'history of philosophy',
#  'general language studies',
#  'algebra',
#  'ecosystems',
#  'evolutionary biology',
#  'eHealth',
#  'facial recognition',
#  'electronic engineering',
#  'electron microscopy',
#  'linear algebra',
#  'water management',
#  'archaeometry',
#  'neurobiology',
#  'evolutionary ecology',
#  'microtechnology',
#  'cervical cancer',
#  'nursing',
#  'history of medicine',
#  'cryptography',
#  'bioprocessing technologies',
#  'asteroseismology',
#  'remote sensing',
#  'supernova',
#  'wave power',
#  'medical laboratory technology',
#  'performing arts',
#  'marine energy',
#  'botany',
#  'pandemics',
#  'obesity',
#  'religions',
#  'library sciences',
#  'physical sciences',
#  'superconductivity',
#  'ornithology',
#  'astronomy',
#  'arithmetics',
#  'graft versus host disease',
#  'dark matter',
#  'commerce',
#  'image recognition',
#  'chemical process engineering',
#  'electrocatalysis',
#  'gender equality',
#  'visual arts',
#  'two-dimensional nanostructures',
#  'mineralogy',
#  'endocrinology',
#  'quantum gases',
#  'volatile organic compounds',
#  'obsessive-compulsive disorder',
#  'geomorphology',
#  'leptons',
#  'biogeochemistry',
#  'cells technologies',
#  'freight transport',
#  'bioremediation',
#  'hepatology',
#  'biological sciences',
#  'public administration',
#  'biological morphology',
#  'regional human rights',
#  'epidemiology',
#  'photovoltaic',
#  'political philosophy',
#  'astronautical engineering',
#  'solar physics',
#  'medieval history',
#  'employment',
#  'international protection of human rights',
#  'polyhydroxyalkanoates',
#  'palynology',
#  'other medical sciences',
#  'semiconductivity',
#  'heat engineering',
#  'reinforcement learning',
#  'DNA',
#  'political communication',
#  'observational astronomy',
#  'aircraft',
#  'amines',
#  'tribology',
#  'and fisheries',
#  'diabetes',
#  'transport',
#  'international law',
#  'pneumology',
#  'sustainable transport',
#  'meteorology',
#  'cognitive psychology',
#  'skin cancer',
#  'multiphysics',
#  'simulation software',
#  'folklore',
#  'big data',
#  'gerontology',
#  'control systems',
#  'pattern recognition',
#  'dynamical systems',
#  'manufacturing engineering',
#  'inflammatory diseases',
#  'spacecraft',
#  'epilepsy',
#  'developmental biology',
#  'medical biotechnology',
#  'genetic engineering',
#  'ethology',
#  'organic acids',
#  'democracy',
#  'government systems',
#  'ozone depletion',
#  'personalized medicine',
#  'electric batteries',
#  'apidology',
#  'operating systems',
#  'stellar astronomy',
#  'plasma physics',
#  'fruit growing',
#  'mathematical model',
#  'nucleic acids',
#  'knowledge engineering',
#  'knowledge organization',
#  'aromatic compounds',
#  'mathematical analysis',
#  'diagnostic technologies',
#  'architecture engineering',
#  'dermatology',
#  'electric vehicles',
#  'electromagnetism',
#  'graph theory',
#  'natural disasters',
#  'wearable medical technology',
#  'black holes',
#  'transition metals',
#  'mechatronics',
#  'quantum physics',
#  'separation technologies',
#  'optical networks',
#  'cytology',
#  'polymer sciences',
#  'ethnoarchaeology',
#  'chemical sciences',
#  'epigenetics',
#  'anthropology',
#  'coronaviruses',
#  'thermodynamics',
#  'economics',
#  'cosmochemistry',
#  'agriculture',
#  'nuclear physics',
#  'surgery',
#  'animal and dairy science',
#  'postnatal care',
#  'system software',
#  'coal',
#  'physical cosmology',
#  'biochemical engineering',
#  'quantum field theory',
#  'gender inequality',
#  'nuclear chemistry',
#  'data networks',
#  'agronomy',
#  'topology',
#  'vegetable growing',
#  'allergology',
#  'functional analysis',
#  'seismology',
#  'organic reactions',
#  'essays',
#  'meteorites',
#  'differential equations',
#  'mobile network',
#  'hydroelectricity',
#  'photocatalysis',
#  'mobile phones',
#  'sustainable architecture',
#  'e-governance',
#  'laser physics',
#  'physical chemistry',
#  'pathophysiology',
#  'parasitology',
#  'cultural and economic geography',
#  'atomic physics',
#  'radiation chemistry',
#  'earth and related environmental sciences',
#  'demography',
#  'implants',
#  'health economics',
#  'political violence',
#  'antibiotic resistance',
#  'calorimetry',
#  'fuel cells',
#  'social psychology',
#  'languages and literature',
#  'art history',
#  'ergonomics',
#  'sexual violence',
#  'biochemistry',
#  'molecular biology',
#  'ethnolichenology',
#  'toxicology',
#  'numerical analysis',
#  'business and management',
#  'virtual reality',
#  'infrared astronomy',
#  'partial differential equations',
#  'immunology',
#  'software applications',
#  'arboriculture',
#  'logarithmic functions',
#  'planets',
#  'bioreactors',
#  'arteriosclerosis',
#  'forestry',
#  'automotive engineering',
#  'telecommunications networks',
#  'linguistics',
#  'quarks',
#  'invertebrate zoology',
#  'radio astronomy',
#  'vaccines',
#  'electric energy',
#  'acoustics',
#  'fertility',
#  'unsupervised learning',
#  'aldehydes',
#  'microscopy',
#  'invasive species',
#  'symplectic topology',
#  'sustainable building',
#  'multidrug resistance',
#  'eastern religions',
#  'mammalogy',
#  'natural satellites',
#  'computational fluid dynamics',
#  'electrical engineering',
#  'solid mechanics',
#  'racial inequality',
#  'muslim culture',
#  'space exploration',
#  'educational sciences',
#  'structural biology',
#  'nonlinear optics',
#  'optics',
#  'other engineering and technologies',
#  'colors',
#  'physiology',
#  'inclusive education',
#  'stroke',
#  'computational creativity',
#  'zoonosis',
#  'fluorescence lifetime imaging',
#  'biomass',
#  'viral genomes']

# %%
print (len(refs))
# Out:
# 803

# %%
projects_no_widening['fundingScheme'].unique()
# Out:
# array(['HORIZON-ERC', 'HORIZON-RIA', 'HORIZON-ERC-SYG', 'HORIZON-JU-RIA',
#        'HORIZON-IA', 'HORIZON-TMA-MSCA-PF-GF', 'HORIZON-CSA',
#        'HORIZON-COFUND', 'ERC', 'HORIZON-JU-IA', 'HORIZON-TMA-MSCA-SE',
#        'HORIZON-TMA-MSCA-Cofund-D', 'HORIZON-TMA-MSCA-Cofund-P',
#        'HORIZON-TMA-MSCA-PF-EF', 'HORIZON-TMA-MSCA-DN',
#        'HORIZON-TMA-MSCA-DN-JD', 'HORIZON-TMA-MSCA-DN-ID', 'EURATOM-IA',
#        'EURATOM-RIA', 'HORIZON-EIC', 'HORIZON-EIC-ACC-BF'], dtype=object)

# %%
projects_filt = projects_no_widening[projects_no_widening['fundingScheme'].isin(['HORIZON-RIA','RIA'])]

# %%
projects_filt
# Out:
#               id        acronym  status  \
# 5      101147312         SAGELI  SIGNED
# 38     101155852       PIPELINE  SIGNED
# 40     101155955      FluiDx-AD  SIGNED
# 49     101138319          ROSAS  SIGNED
# 74     101191726  KeratOPrinter  SIGNED
# ...          ...            ...     ...
# 13670  101130442        BioBIVE  SIGNED
# 13708  101178484        GEAR-UP  SIGNED
# 13719  101147799         UPBEAT  SIGNED
# 13766  101191948        PECATHS  SIGNED
# 13769  101184989  NextGenCarbon  SIGNED
#
#                                                    title  startDate  \
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# 38     Pregnancy and Infant PrEparedness pLatform IN ... 2025-01-01
# 40     A novel test trio to detect peptide biomarkers... 2024-11-01
# 49     RObust simulation Systems exploiting AI based ... 2025-01-01
# 74     Advanced 4D Printing Technologies in Corneal R... 2025-01-01
# ...                                                  ...        ...
# 13670  BIOdegradable delivery systems for plant patho... 2024-06-01
# 13708  Green Engineering, Analysis, & Reskilling for ... 2024-10-01
# 13719  Uncertainty Prediction & Bias Elimination in A... 2024-05-01
# 13766  PHOTO-ELECTROCATALYTIC ROUTES FOR LONG-TERM SU... 2025-01-01
# 13769  Next Generation Modelling of Terrestrial Carbo... 2025-01-01
#
#          endDate   totalCost ecMaxContribution   legalBasis  \
# 5     2027-12-31  4975670,75        4975669,75  HORIZON.2.5
# 38    2028-12-31           0        9999975,25  HORIZON.2.1
# 40    2028-04-30           0        7699219,38  HORIZON.2.1
# 49    2028-06-30  4630603,46        4630603,46  HORIZON.2.5
# 74    2029-12-31  7999581,25        7999581,25  HORIZON.2.1
# ...          ...         ...               ...          ...
# 13670 2028-05-31     6851903           6851903  HORIZON.2.4
# 13708 2028-09-30  5999683,75        5999683,75  HORIZON.2.4
# 13719 2027-10-31  3999893,25        3999893,25  HORIZON.2.5
# 13766 2028-12-31   2049322,5         2049322,5  HORIZON.2.5
# 13769 2029-12-31  9999846,25        9999846,25  HORIZON.2.5
#
#                                           topics ecSignatureDate  \
# 5                      HORIZON-CL5-2023-D2-02-02      2024-11-18
# 38     HORIZON-HLTH-2024-DISEASE-03-11-two-stage      2024-11-29
# 40     HORIZON-HLTH-2024-DISEASE-03-13-two-stage      2024-11-29
# 49                     HORIZON-CL5-2023-D5-01-09      2024-12-02
# 74                  HORIZON-HLTH-2024-TOOL-11-02      2024-11-29
# ...                                          ...             ...
# 13670          HORIZON-CL4-2023-RESILIENCE-01-34      2024-05-15
# 13708     HORIZON-CL4-2024-TWIN-TRANSITION-01-05      2024-09-20
# 13719                  HORIZON-CL5-2023-D6-01-11      2024-04-10
# 13766                  HORIZON-CL5-2024-D2-01-04      2024-11-07
# 13769                  HORIZON-CL5-2024-D1-01-07      2024-10-21
#
#       frameworkProgramme                                masterCall  \
# 5                HORIZON                    HORIZON-CL5-2023-D2-02
# 38               HORIZON    HORIZON-HLTH-2024-DISEASE-03-two-stage
# 40               HORIZON    HORIZON-HLTH-2024-DISEASE-03-two-stage
# 49               HORIZON                    HORIZON-CL5-2023-D5-01
# 74               HORIZON                 HORIZON-HLTH-2024-TOOL-11
# ...                  ...                                       ...
# 13670            HORIZON  HORIZON-CL4-2023-RESILIENCE-01-TWO-STAGE
# 13708            HORIZON       HORIZON-CL4-2024-TWIN-TRANSITION-01
# 13719            HORIZON                    HORIZON-CL5-2023-D6-01
# 13766            HORIZON                    HORIZON-CL5-2024-D2-01
# 13769            HORIZON                    HORIZON-CL5-2024-D1-01
#
#                                         subCall fundingScheme  nature  \
# 5                        HORIZON-CL5-2023-D2-02   HORIZON-RIA     NaN
# 38       HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA     NaN
# 40       HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA     NaN
# 49                       HORIZON-CL5-2023-D5-01   HORIZON-RIA     NaN
# 74                    HORIZON-HLTH-2024-TOOL-11   HORIZON-RIA     NaN
# ...                                         ...           ...     ...
# 13670  HORIZON-CL4-2023-RESILIENCE-01-TWO-STAGE   HORIZON-RIA     NaN
# 13708       HORIZON-CL4-2024-TWIN-TRANSITION-01   HORIZON-RIA     NaN
# 13719                    HORIZON-CL5-2023-D6-01   HORIZON-RIA     NaN
# 13766                    HORIZON-CL5-2024-D2-01   HORIZON-RIA     NaN
# 13769                    HORIZON-CL5-2024-D1-01   HORIZON-RIA     NaN
#
#                                                objective    contentUpdateDate  \
# 5      SAGELi aims to develop safer materials and cel...  2024-12-12 11:00:23
# 38     Recent epidemics have highlighted how infectio...  2024-12-12 10:52:37
# 40     FluiDx-AD aims to transform Alzheimer’s diseas...  2024-12-12 10:53:51
# 49     To meet global EU objectives related to aerona...  2024-12-12 10:49:05
# 74     Corneal blindness is the 3rd leading cause of ...  2024-12-11 16:34:03
# ...                                                  ...                  ...
# 13670  The BioBIVE Consortium is a multidisciplinary ...  2024-05-20 14:28:53
# 13708  The GEAR-UP proposal, is a comprehensive initi...  2024-10-03 16:12:34
# 13719  Understanding and quantifying uncertainties (U...  2024-04-18 12:39:19
# 13766  PeCATHS is committed to developing an integrat...  2024-11-15 16:34:04
# 13769  The ability to evaluate EU's climate and susta...  2024-11-01 18:00:49
#
#           rcn           grantDoi
# 5      267735  10.3030/101147312
# 38     267995  10.3030/101155852
# 40     267997  10.3030/101155955
# 49     267986  10.3030/101138319
# 74     268028  10.3030/101191726
# ...       ...                ...
# 13670  263531  10.3030/101130442
# 13708  266060  10.3030/101178484
# 13719  262664  10.3030/101147799
# 13766  267378  10.3030/101191948
# 13769  267098  10.3030/101184989
#
# [111 rows x 20 columns]

# %%
projects_ = projects_filt[['id','acronym','title','startDate','endDate','totalCost','legalBasis','topics','masterCall','subCall','fundingScheme','objective','grantDoi']]

# %%
projects_['topics'].tolist()
# Out:
# ['HORIZON-CL5-2023-D2-02-02',
#  'HORIZON-HLTH-2024-DISEASE-03-11-two-stage',
#  'HORIZON-HLTH-2024-DISEASE-03-13-two-stage',
#  'HORIZON-CL5-2023-D5-01-09',
#  'HORIZON-HLTH-2024-TOOL-11-02',
#  'HORIZON-CL5-2024-D5-01-02',
#  'HORIZON-CL5-2023-D3-03-01',
#  'HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-HLTH-2024-IND-06-08',
#  'HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-CL4-2023-HUMAN-01-13',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-EUSPA-2023-SPACE-01-43',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL5-2024-D5-01-08',
#  'HORIZON-CL5-2024-D5-01-18',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-06',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL4-2023-RESILIENCE-01-23',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-03',
#  'HORIZON-CL5-2024-D2-01-01',
#  'HORIZON-CL5-2024-D3-01-04',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-40',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-01',
#  'HORIZON-HLTH-2024-STAYHLTH-01-05-two-stage',
#  'HORIZON-CL5-2023-D3-02-02',
#  'HORIZON-CL5-2024-D3-01-14',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-HLTH-2023-IND-06-04',
#  'HORIZON-CL5-2023-D1-01-11',
#  'HORIZON-HLTH-2023-DISEASE-03-03',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-3',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-HLTH-2023-TOOL-05-04',
#  'HORIZON-HLTH-2024-DISEASE-03-08-two-stage',
#  'HORIZON-MISS-2023-CANCER-01-03',
#  'HORIZON-HLTH-2022-DISEASE-07-03',
#  'HORIZON-CL5-2024-D3-01-04',
#  'HORIZON-CL5-2023-D3-02-07',
#  'HORIZON-CL5-2023-D3-02-15',
#  'HORIZON-CL6-2023-BIODIV-01-2',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-CL2-2024-DEMOCRACY-01-09',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-11',
#  'HORIZON-CL6-2023-FARM2FORK-01-20',
#  'HORIZON-CL4-2023-RESILIENCE-01-33',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-05',
#  'HORIZON-CL4-2023-SPACE-01-22',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-CL5-2024-D5-01-07',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-CL5-2023-D5-01-09',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-12',
#  'HORIZON-CL2-2024-HERITAGE-01-05',
#  'HORIZON-CL2-2024-DEMOCRACY-01-07',
#  'HORIZON-MISS-2023-CANCER-01-01',
#  'HORIZON-HLTH-2023-DISEASE-03-17',
#  'HORIZON-CL5-2024-D1-01-06',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-CL5-2023-D1-01-02',
#  'HORIZON-CL5-2023-D3-02-07',
#  'HORIZON-CL5-2024-D1-01-02',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-21',
#  'HORIZON-CL5-2023-D5-01-11',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-HLTH-2023-TOOL-05-03',
#  'HORIZON-INFRA-2023-TECH-01-01',
#  'HORIZON-HLTH-2023-DISEASE-03-17',
#  'HORIZON-CL4-2023-SPACE-01-72',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL5-2023-D3-01-13',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-3',
#  'HORIZON-HLTH-2023-ENVHLTH-02-03',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-45',
#  'HORIZON-CL5-2023-D5-01-11',
#  'HORIZON-MISS-2023-CANCER-01-03',
#  'HORIZON-HLTH-2022-DISEASE-06-04-two-stage',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-31',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-36',
#  'HORIZON-CL5-2023-D3-02-05',
#  'HORIZON-CL5-2024-D3-01-07',
#  'HORIZON-CL2-2024-HERITAGE-01-05',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-11',
#  'HORIZON-HLTH-2023-DISEASE-03-18',
#  'HORIZON-HLTH-2024-ENVHLTH-02-06-two-stage',
#  'HORIZON-CL6-2022-FARM2FORK-01-09',
#  'HORIZON-HLTH-2023-ENVHLTH-02-03',
#  'HORIZON-CL5-2024-D1-01-03',
#  'HORIZON-CL5-2023-D1-01-02',
#  'HORIZON-CL5-2023-D3-01-05',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-HLTH-2024-TOOL-05-06-two-stage',
#  'HORIZON-HLTH-2023-TOOL-05-03',
#  'HORIZON-INFRA-2024-DEV-01-03',
#  'HORIZON-HLTH-2023-ENVHLTH-02-01',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-CL5-2024-D1-01-02',
#  'HORIZON-INFRA-2024-TECH-01-01',
#  'HORIZON-CL5-2023-D1-01-01',
#  'HORIZON-CL5-2023-D3-02-05',
#  'HORIZON-CL5-2024-D3-01-15',
#  'HORIZON-CL5-2023-D3-02-15',
#  'HORIZON-CL4-2023-RESILIENCE-01-34',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-05',
#  'HORIZON-CL5-2023-D6-01-11',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-CL5-2024-D1-01-07']

# %%
# Define function to assign clusters
def assign_cluster(topic):
    if "CL2" in topic:
        return "Cluster 2"
    elif "CL3" in topic:
        return "Cluster 3"
    elif "CL4" in topic:
        return "Cluster 4"
    elif "CL5" in topic:
        return "Cluster 5"
    elif "CL6" in topic:
        return "Cluster 6"
    elif "HLTH" in topic:
        return "Cluster Health"
    elif "MISS" in topic:
        return "Cluster MISS"
    else:
        return "Other"

# Apply function to create a new column
projects_["cluster"] = projects_["topics"].apply(assign_cluster)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23328\2163152521.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   projects_["cluster"] = projects_["topics"].apply(assign_cluster)

# %%
projects_
# Out:
#               id        acronym  \
# 5      101147312         SAGELI
# 38     101155852       PIPELINE
# 40     101155955      FluiDx-AD
# 49     101138319          ROSAS
# 74     101191726  KeratOPrinter
# ...          ...            ...
# 13670  101130442        BioBIVE
# 13708  101178484        GEAR-UP
# 13719  101147799         UPBEAT
# 13766  101191948        PECATHS
# 13769  101184989  NextGenCarbon
#
#                                                    title  startDate  \
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# 38     Pregnancy and Infant PrEparedness pLatform IN ... 2025-01-01
# 40     A novel test trio to detect peptide biomarkers... 2024-11-01
# 49     RObust simulation Systems exploiting AI based ... 2025-01-01
# 74     Advanced 4D Printing Technologies in Corneal R... 2025-01-01
# ...                                                  ...        ...
# 13670  BIOdegradable delivery systems for plant patho... 2024-06-01
# 13708  Green Engineering, Analysis, & Reskilling for ... 2024-10-01
# 13719  Uncertainty Prediction & Bias Elimination in A... 2024-05-01
# 13766  PHOTO-ELECTROCATALYTIC ROUTES FOR LONG-TERM SU... 2025-01-01
# 13769  Next Generation Modelling of Terrestrial Carbo... 2025-01-01
#
#          endDate   totalCost   legalBasis  \
# 5     2027-12-31  4975670,75  HORIZON.2.5
# 38    2028-12-31           0  HORIZON.2.1
# 40    2028-04-30           0  HORIZON.2.1
# 49    2028-06-30  4630603,46  HORIZON.2.5
# 74    2029-12-31  7999581,25  HORIZON.2.1
# ...          ...         ...          ...
# 13670 2028-05-31     6851903  HORIZON.2.4
# 13708 2028-09-30  5999683,75  HORIZON.2.4
# 13719 2027-10-31  3999893,25  HORIZON.2.5
# 13766 2028-12-31   2049322,5  HORIZON.2.5
# 13769 2029-12-31  9999846,25  HORIZON.2.5
#
#                                           topics  \
# 5                      HORIZON-CL5-2023-D2-02-02
# 38     HORIZON-HLTH-2024-DISEASE-03-11-two-stage
# 40     HORIZON-HLTH-2024-DISEASE-03-13-two-stage
# 49                     HORIZON-CL5-2023-D5-01-09
# 74                  HORIZON-HLTH-2024-TOOL-11-02
# ...                                          ...
# 13670          HORIZON-CL4-2023-RESILIENCE-01-34
# 13708     HORIZON-CL4-2024-TWIN-TRANSITION-01-05
# 13719                  HORIZON-CL5-2023-D6-01-11
# 13766                  HORIZON-CL5-2024-D2-01-04
# 13769                  HORIZON-CL5-2024-D1-01-07
#
#                                      masterCall  \
# 5                        HORIZON-CL5-2023-D2-02
# 38       HORIZON-HLTH-2024-DISEASE-03-two-stage
# 40       HORIZON-HLTH-2024-DISEASE-03-two-stage
# 49                       HORIZON-CL5-2023-D5-01
# 74                    HORIZON-HLTH-2024-TOOL-11
# ...                                         ...
# 13670  HORIZON-CL4-2023-RESILIENCE-01-TWO-STAGE
# 13708       HORIZON-CL4-2024-TWIN-TRANSITION-01
# 13719                    HORIZON-CL5-2023-D6-01
# 13766                    HORIZON-CL5-2024-D2-01
# 13769                    HORIZON-CL5-2024-D1-01
#
#                                         subCall fundingScheme  \
# 5                        HORIZON-CL5-2023-D2-02   HORIZON-RIA
# 38       HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA
# 40       HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA
# 49                       HORIZON-CL5-2023-D5-01   HORIZON-RIA
# 74                    HORIZON-HLTH-2024-TOOL-11   HORIZON-RIA
# ...                                         ...           ...
# 13670  HORIZON-CL4-2023-RESILIENCE-01-TWO-STAGE   HORIZON-RIA
# 13708       HORIZON-CL4-2024-TWIN-TRANSITION-01   HORIZON-RIA
# 13719                    HORIZON-CL5-2023-D6-01   HORIZON-RIA
# 13766                    HORIZON-CL5-2024-D2-01   HORIZON-RIA
# 13769                    HORIZON-CL5-2024-D1-01   HORIZON-RIA
#
#                                                objective           grantDoi  \
# 5      SAGELi aims to develop safer materials and cel...  10.3030/101147312
# 38     Recent epidemics have highlighted how infectio...  10.3030/101155852
# 40     FluiDx-AD aims to transform Alzheimer’s diseas...  10.3030/101155955
# 49     To meet global EU objectives related to aerona...  10.3030/101138319
# 74     Corneal blindness is the 3rd leading cause of ...  10.3030/101191726
# ...                                                  ...                ...
# 13670  The BioBIVE Consortium is a multidisciplinary ...  10.3030/101130442
# 13708  The GEAR-UP proposal, is a comprehensive initi...  10.3030/101178484
# 13719  Understanding and quantifying uncertainties (U...  10.3030/101147799
# 13766  PeCATHS is committed to developing an integrat...  10.3030/101191948
# 13769  The ability to evaluate EU's climate and susta...  10.3030/101184989
#
#               cluster
# 5           Cluster 5
# 38     Cluster Health
# 40     Cluster Health
# 49          Cluster 5
# 74     Cluster Health
# ...               ...
# 13670       Cluster 4
# 13708       Cluster 4
# 13719       Cluster 5
# 13766       Cluster 5
# 13769       Cluster 5
#
# [111 rows x 14 columns]

# %%
projects_.to_csv('../data/processed/projects.csv',index=False,sep='|')

# %%
orgs_ = orgs_no_widening[orgs_no_widening['projectID'].isin(projects_['id'].tolist())]

# %%
orgs_
# Out:
#        projectID projectAcronym  organisationID       vatNumber  \
# 45     101147312         SAGELI       912743326     ESB98896137
# 46     101147312         SAGELI       881331040   IT03941241204
# 47     101147312         SAGELI       999980470     DE122624631
# 48     101147312         SAGELI       999992401   FR43775685019
# 49     101147312         SAGELI       962434389     ESG01241876
# ...          ...            ...             ...             ...
# 90905  101184989  NextGenCarbon       999981634  NL811383696B01
# 90906  101184989  NextGenCarbon       999990267     DE129517720
# 90907  101184989  NextGenCarbon       999419422   IT03873750750
# 90908  101184989  NextGenCarbon       999837104   FR25197819444
# 90909  101184989  NextGenCarbon       999547365  NL806511618B01
#
#                                                     name        shortName  \
# 45                                           LOMARTOV SL              NaN
# 46                                      POWER4FUTURE SPA     POWER4FUTURE
# 47                         FORSCHUNGSZENTRUM JULICH GMBH              FZJ
# 48     COMMISSARIAT A L ENERGIE ATOMIQUE ET AUX ENERG...              CEA
# 49     CENTRO DE INVESTIGACION COOPERATIVA DE ENERGIA...   CIC ENERGIGUNE
# ...                                                  ...              ...
# 90905                              WAGENINGEN UNIVERSITY               WU
# 90906  MAX-PLANCK-GESELLSCHAFT ZUR FORDERUNG DER WISS...              MPG
# 90907  FONDAZIONE CENTRO EURO-MEDITERRANEOSUI CAMBIAM...  FONDAZIONE CMCC
# 90908  UNIVERSITE DE VERSAILLES SAINT-QUENTIN-EN-YVEL...              NaN
# 90909                      STICHTING WAGENINGEN RESEARCH               WR
#
#          SME activityType                                             street  \
# 45      True          PRC                                 CALLE ALFARERIA, 3
# 46     False          PRC                            VIA STELLONI PONENTE 33
# 47     False          REC                             WILHELM JOHNEN STRASSE
# 48     False          REC                                    RUE LEBLANC  25
# 49     False          REC  CALLE ALBERT EINSTEIN 48 PARQUE TECNOLOGICO DE...
# ...      ...          ...                                                ...
# 90905  False          HES                               DROEVENDAALSESTEEG 4
# 90906  False          REC                                 HOFGARTENSTRASSE 8
# 90907  False          REC                                  VIA MARCO BIAGI 5
# 90908  False          HES                                 AVENUE DE PARIS 55
# 90909  False          REC                               DROEVENDAALSESTEEG 4
#
#       postCode  ...                                        contactForm  \
# 45       46100  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 46       40012  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 47       52428  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 48       75015  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 49       01510  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# ...        ...  ...                                                ...
# 90905  6708 PB  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 90906    80539  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 90907    73100  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 90908    78035  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 90909  6708 PB  ...  https://ec.europa.eu/info/funding-tenders/oppo...
#
#          contentUpdateDate      rcn order         role ecContribution  \
# 45     2024-12-12 11:00:23  3146679   8.0  participant      281250.00
# 46     2024-12-12 11:00:23  1990776  11.0  participant      156125.00
# 47     2024-12-12 11:00:23  1905734   4.0  participant      425297.50
# 48     2024-12-12 11:00:23  1905694   1.0  coordinator     1383646.00
# 49     2024-12-12 11:00:23  1915266   7.0  participant      447680.00
# ...                    ...      ...   ...          ...            ...
# 90905  2024-11-01 18:00:49  1906458   4.0  participant      399625.00
# 90906  2024-11-01 18:00:49  1949732   7.0  participant      760000.00
# 90907  2024-11-01 18:00:49  1907880  16.0  participant      230000.00
# 90908  2024-11-01 18:00:49  1912635   2.0  participant      879937.50
# 90909  2024-11-01 18:00:49  1906407   3.0  participant      456531.25
#
#       netEcContribution  totalCost  endOfParticipation active
# 45            281250.00     281250               False    NaN
# 46             89687.50     156125               False    NaN
# 47            425297.50   425297,5               False    NaN
# 48           1383646.00    1383647               False    NaN
# 49            447680.00     447680               False    NaN
# ...                 ...        ...                 ...    ...
# 90905         399625.00     399625               False    NaN
# 90906         760000.00     760000               False    NaN
# 90907         230000.00     230000               False    NaN
# 90908         879937.50   879937,5               False    NaN
# 90909         456531.25  456531,25               False    NaN
#
# [1196 rows x 25 columns]

# %%
orgs_ = orgs_[['projectID','name','shortName','SME','activityType','city','country','organizationURL','contactForm','order','role','ecContribution']]

# %%
print (orgs_['country'].unique())
# Out:
# ['ES' 'IT' 'DE' 'FR' 'BE' 'NL' 'UK' 'FI' 'NO' 'LU' 'SE' 'IE' 'AT' 'CH'
#  'GT' 'US' 'IN' 'MV' 'IL' 'DK' 'KE' 'ZA' 'MG' 'TZ' 'BF' 'CN' 'GL' 'CA'
#  'GH' 'AU' 'BJ' 'NG' 'CI' 'AW' 'CO' 'AR' 'CL' 'IS' 'KR' 'JP' 'PH' 'MC']

# %%
orgs_.to_csv('../data/processed/orgs.csv',index=False,sep='|')
